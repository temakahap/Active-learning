# %%
import pandas as pd
import numpy as np
import subprocess
import random
from tqdm import tqdm_notebook
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor

# %%
INIT_COUNT = 2000
COUNT_TO_ADD = 50
TARGET = np.zeros(1000000)
list_of_initial_index = []
RFR = RandomForestRegressor(n_estimators = 150, n_jobs=-1)
BAGG = BaggingRegressor(n_estimators = 150, n_jobs=-1)
GDR = GradientBoostingRegressor(n_estimators=150, learning_rate=0.075)
ADA = AdaBoostRegressor(n_estimators=150, learning_rate=0.01)
models = [RFR, BAGG, GDR, ADA]

# %%
#Выгрузка данных и права на исполнение бинарника.
df = pd.read_csv('X_public.csv')
data = df.values[:, 1:]
# !chmod 755 ./Oracle.static 
data.shape
# Out:
# (1000000, 10)

# %%
def to_str(x):
    f = str()
    f+=str(x[0])
    for item in x[1:]:
        f += ' ' + str(item)
    return f

def get_models_pred(X, y):
    list_of_preds = []
    for model in tqdm_notebook(models):
        model.fit(X_train_init, y_train_init)
        list_of_preds.append(model.predict(data))
    return list_of_preds

def get_new_target_value(new_index, count = COUNT_TO_ADD):
    for i in range(count):
        m = to_str(data[new_ind[i]])
        #print (m)
        Out = !./Oracle.static $m
        TARGET[new_ind[i]] = Out[0]
        #print(new_ind[i], Out[0])

# %%
#Начальная инициализация точек.
for _ in range(INIT_COUNT):
    now_ind = np.random.randint(1000000)
    list_of_initial_index.append(now_ind)

for i in range(INIT_COUNT):
    if (i%30 == 0):
        print (i)
    m = to_str(data[list_of_initial_index[i]])
    #print (m)
    Out = !./Oracle.static $m
    #ind[list_of_initial_index[i]] = Out[0]
    TARGET[list_of_initial_index[i]] = Out[0]
    #print(list_of_initial_index[i], Out[0])
# Out:
# 0
# 30
# 60
# 90
# 120
# 150
# 180
# 210
# 240
# 270
# 300
# 330
# 360
# 390
# 420
# 450
# 480
# 510
# 540
# 570
# 600
# 630
# 660
# 690
# 720
# 750
# 780
# 810
# 840
# 870
# 900
# 930
# 960
# 990
# 1020
# 1050
# 1080
# 1110
# 1140
# 1170
# 1200
# 1230
# 1260
# 1290
# 1320
# 1350
# 1380
# 1410
# 1440
# 1470
# 1500
# 1530
# 1560
# 1590
# 1620
# 1650
# 1680
# 1710
# 1740
# 1770
# 1800
# 1830
# 1860
# 1890
# 1920
# 1950
# 1980

# %%
len(list_of_initial_index)
data
COUNT_TO_ADD = 50

# %%
#new_final_ind = list(np.unique(list_of_initial_index))
inde = 0


    
for _ in range(1000):
    
    print ("NEW ORACLE ERA HAS BEGAN.")
    inde+=1
    print ("Number of iteration is", inde)
    print ("\n")
    
    #Получаем разброс предсказаний комитета алгоритма.
    #print ("Getting std's of comitet.")
    print ("Длина данных для обучения", np.unique(new_final_ind).shape, len(new_final_ind))
    X_train_new = data[new_final_ind]
    y_train_new = TARGET[new_final_ind]
    RFR_train = RandomForestRegressor(n_estimators=400, max_depth=4)
    print ("Fit algortithm.")
    RFR_train.fit(X_train_new, y_train_new)
    pred1 = RFR_train.predict(X_train_new)
    
    #Получаем список ощибок для модели, ищем точки, на которых ошибка больше всего.
    err = np.abs(pred1 - y_train_new)
    GDR_error = GradientBoostingRegressor(n_estimators=400, max_depth=4)
    print ("Fit algortithm on errors.")

    GDR_error.fit(X_train_new, err)
    pred_errs = np.abs(RFR_error.predict(data)) 
    
    #Вопрос - нужна ли эта опция? По идее да, пока оставлю.
    pred_errs[new_final_ind] = 0
    
    #Получаем список точек с наибольшей ошибкой по предиктам моделей.
    new_ind = pred_errs.argsort()[::-1][:COUNT_TO_ADD]
    print (new_ind)
    print ('\n')
    print (pred_errs[new_ind])
        
    #Получаем таргет новых точек
    print ("Getting new target values.")

    get_new_target_value(new_ind)
    new_final_ind = list(np.unique(new_final_ind + list(new_ind)))
    #X_train_new = data[new_final_ind]
    #y_train_new = TARGET[new_final_ind]
# Out:
# NEW ORACLE ERA HAS BEGAN.
# Number of iteration is 1
#
#
# Длина данных для обучения (2898,) 2898
# Fit algortithm.
# Fit algortithm on errors.
# [307307 724313 691513 553150 870981 964079 517996 734334 890181 972017
#  415616 666365 819745 517836 896743 379249 886140 604829  24564 386699
#  563668 403149 610118 258790  14196 789217 150321 867316 965485 453986
#  132470 419589  43910 463630 650704 675842 458023 119729 969160 396523
#  224487  53571 291505 129364 161423 276194 886453 787166 902184  29110]
#
#
# [  1.34866116e+48   1.34718313e+48   1.34192407e+48   1.34142462e+48
#    1.34083310e+48   1.34083310e+48   1.33410214e+48   1.33410214e+48
#    1.33410214e+48   1.33410214e+48   1.33410214e+48   1.30138890e+48
#    1.28718262e+48   1.28619607e+48   1.28504355e+48   1.28106062e+48
#    1.27881778e+48   1.27881778e+48   1.27828682e+48   1.27828682e+48
#    1.27824808e+48   1.27621585e+48   1.27604398e+48   1.27432966e+48
# ...

# %%
np.unique(new_final_ind).shape
# Out:
# (14048,)

# %%
RFR_train_fin = RandomForestRegressor(n_estimators=400, max_depth=4)
RFR_train_fin.fit(data[np.unique(np.array(new_final_ind))], TARGET[np.unique(np.array(new_final_ind))])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=4,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=400, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred = RFR_train_fin.predict(data)
pred[np.unique(np.array(new_final_ind))] = TARGET[np.unique(np.array(new_final_ind))]

# %%
pred[pred.argsort()]
# Out:
# array([ -7.99509119e+02,  -1.10542240e+02,  -9.53809517e+01, ...,
#          1.38269826e+50,   1.48489243e+50,   1.56172900e+50])

# %%
df_answer = pd.DataFrame()
df_answer['Id'] = df['Id']
df_answer['target'] = pred
df_answer = df_answer.set_index('Id')
df_answer = df_answer.fillna(0)
df_answer.to_csv('submit.csv')

# %%
import pickle
with open('target.pickle', 'wb') as f1:
    pickle.dump(TARGET, f1) 
with open('index.pickle', 'wb') as f1:
    pickle.dump(new_final_ind, f1)

# %%
import multiprocessing
num_cores = multiprocessing.cpu_count()
num_cores
# Out:
# 4
